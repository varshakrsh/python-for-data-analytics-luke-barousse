# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

#loading data
dataset=load_dataset('lukebarousse/data_jobs')

#converting the loaded dataset into a pandas dataframe
df=dataset['train'].to_pandas()

#formatting datetime
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
#creating a new dataframe with non-NaN average yearly salaries
new_df=df[df['salary_year_avg'].notna()].copy()
new_df
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
#creating a function that multiplies the salary values with an inflation rate of 1.03
def new_salary(salary):
    return 1.03 * salary

# %%
#Applying the function using the .apply() function
new_df['salary_inflation']= new_df['salary_year_avg'].apply(new_salary)
new_df[['salary_year_avg','salary_inflation']]
# Out:
#         salary_year_avg  salary_inflation
# 28             109500.0         112785.00
# 77             140000.0         144200.00
# 92             120000.0         123600.00
# 100            228222.0         235068.66
# 109             89000.0          91670.00
# ...                 ...               ...
# 785624         139216.0         143392.48
# 785641         150000.0         154500.00
# 785648         221875.0         228531.25
# 785682         157500.0         162225.00
# 785692         157500.0         162225.00
#
# [22003 rows x 2 columns]

# %%
#using lambda() function
new_df['salary_inflation']= new_df['salary_year_avg'].apply(lambda salary: salary * 1.03)
new_df[['salary_year_avg','salary_inflation']]
# Out:
#         salary_year_avg  salary_inflation
# 28             109500.0         112785.00
# 77             140000.0         144200.00
# 92             120000.0         123600.00
# 100            228222.0         235068.66
# 109             89000.0          91670.00
# ...                 ...               ...
# 785624         139216.0         143392.48
# 785641         150000.0         154500.00
# 785648         221875.0         228531.25
# 785682         157500.0         162225.00
# 785692         157500.0         162225.00
#
# [22003 rows x 2 columns]

# %%
#creating a custom function that converts the job skills column from string format into list
import ast
def clean_list(skills):
    if pd.notna(skills):
        return ast.literal_eval(skills)

# %%
#applying clean_list() using apply()
new_df['job_skills']=new_df['job_skills'].apply(clean_list)

# %%
#verifying if the job_skills column has been cleaned
type(new_df['job_skills'][28])
# Out:
# list

# %%
#performing this cleaning using lambda()
df['job_skills']=df['job_skills'].apply(lambda skills: ast.literal_eval(skills) if pd.notna(skills) else skills)

# %%
#verifying if the job_skills column has been cleaned
type(df['job_skills'][1])
# Out:
# list

# %%
#creating a function that goes through the job titles, mutiplies the salary with an inflation rate of 1.05 if 'senior' is found in the job title, else mutiplies it with 1.03
def projected_salary(row):
    if 'Senior' in row['job_title_short']:
        return 1.05*row['salary_year_avg']
    else:
        return 1.03*row['salary_year_avg']

# %%
#Applying the created function
new_df['salary_inflation']=new_df.apply(projected_salary, axis=1)
new_df[['job_title_short','salary_year_avg','salary_inflation']].head(25)
# Out:
#           job_title_short  salary_year_avg  salary_inflation
# 28         Data Scientist         109500.0         112785.00
# 77          Data Engineer         140000.0         144200.00
# 92          Data Engineer         120000.0         123600.00
# 100        Data Scientist         228222.0         235068.66
# 109          Data Analyst          89000.0          91670.00
# 116        Data Scientist         114000.0         117420.00
# 146         Data Engineer         129500.0         133385.00
# 180          Data Analyst          90250.0          92957.50
# 212        Data Scientist         157500.0         162225.00
# 257        Data Scientist         103128.0         106221.84
# 307         Data Engineer         185000.0         190550.00
# 339         Data Engineer         195000.0         200850.00
# 380         Data Engineer          97500.0         100425.00
# 388         Data Engineer          89000.0          91670.00
# ...

# %%
#using lambda()
new_df['salary_inflation']=new_df.apply(lambda row:1.05 * row['salary_year_avg'] if 'Senior' in row['job_title_short'] else 1.03 * row['salary_year_avg'], axis =1)
new_df[['job_title_short', 'salary_year_avg', 'salary_inflation']].head(25)
# Out:
#           job_title_short  salary_year_avg  salary_inflation
# 28         Data Scientist         109500.0         112785.00
# 77          Data Engineer         140000.0         144200.00
# 92          Data Engineer         120000.0         123600.00
# 100        Data Scientist         228222.0         235068.66
# 109          Data Analyst          89000.0          91670.00
# 116        Data Scientist         114000.0         117420.00
# 146         Data Engineer         129500.0         133385.00
# 180          Data Analyst          90250.0          92957.50
# 212        Data Scientist         157500.0         162225.00
# 257        Data Scientist         103128.0         106221.84
# 307         Data Engineer         185000.0         190550.00
# 339         Data Engineer         195000.0         200850.00
# 380         Data Engineer          97500.0         100425.00
# 388         Data Engineer          89000.0          91670.00
# ...
